# %%
# NEW
import sys
# !{sys.executable} -m pip install -U kaggle
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import os
os.listdir()
# Out:
# ['Untitled.ipynb', 'kaggle.json', '.ipynb_checkpoints']

# %%
# Cell 3 - Download from Official Source
# !wget -c "https://datashare.ed.ac.uk/bitstream/handle/10283/3336/LA.zip" -O LA.zip
# Out:
# --2026-05-07 12:01:30--  https://datashare.ed.ac.uk/bitstream/handle/10283/3336/LA.zip
# Resolving datashare.ed.ac.uk (datashare.ed.ac.uk)... 129.215.67.172
# Connecting to datashare.ed.ac.uk (datashare.ed.ac.uk)|129.215.67.172|:443... connected.
# HTTP request sent, awaiting response... 200 200
# Length: 7640952520 (7.1G) [application/zip]
# Saving to: ‘LA.zip’
#
# LA.zip              100%[===================>]   7.12G  1.91MB/s    in 37m 31s
#
# 2026-05-07 12:39:04 (3.24 MB/s) - ‘LA.zip’ saved [7640952520/7640952520]

# %%
# Cell 4 - Unzip
# !unzip LA.zip
print("Done!")
# Out:
# Archive:  LA.zip
# Made with MacWinZipper (http://tidajapan.com/macwinzipper)
#   inflating: LA/ASVspoof2019_LA_asv_protocols/ASVspoof2019.LA.asv.eval.gi.trl.txt
#   inflating: LA/ASVspoof2019_LA_asv_protocols/ASVspoof2019.LA.asv.eval.female.trl.txt
#   inflating: LA/ASVspoof2019_LA_asv_protocols/ASVspoof2019.LA.asv.dev.male.trl.txt
#   inflating: LA/ASVspoof2019_LA_asv_protocols/ASVspoof2019.LA.asv.dev.male.trn.txt
#   inflating: LA/ASVspoof2019_LA_asv_protocols/ASVspoof2019.LA.asv.eval.female.trn.txt
#   inflating: LA/ASVspoof2019_LA_asv_protocols/ASVspoof2019.LA.asv.eval.male.trl.txt
#   inflating: LA/ASVspoof2019_LA_asv_protocols/ASVspoof2019.LA.asv.eval.male.trn.txt
#   inflating: LA/ASVspoof2019_LA_asv_protocols/ASVspoof2019.LA.asv.dev.female.trl.txt
#   inflating: LA/ASVspoof2019_LA_asv_protocols/ASVspoof2019.LA.asv.dev.female.trn.txt
#   inflating: LA/ASVspoof2019_LA_asv_protocols/ASVspoof2019.LA.asv.dev.gi.trl.txt
# ...

# %%
# Cell 5 - Verify
import os
print(os.listdir())
# Out:
# ['Untitled.ipynb', 'asvspoof.zip', 'LA.zip', 'LA', 'kaggle.json', '.ipynb_checkpoints']

# %%
import os

for folder in os.listdir("LA"):
    print(folder)
# Out:
# ASVspoof2019_LA_asv_protocols
# ASVspoof2019_LA_train
# README.LA.txt
# ASVspoof2019_LA_asv_scores
# ASVspoof2019_LA_dev
# ASVspoof2019_LA_eval
# ASVspoof2019_LA_cm_protocols

# %%
import os

os.remove("asvspoof.zip")   # failed/empty zip from wget
os.remove("LA.zip")         # already extracted, no longer needed
print("Cleaned up!")
# Out:
# Cleaned up!

# %%
import os

for item in sorted(os.listdir("LA")):
    print(item)
# Out:
# ASVspoof2019_LA_asv_protocols
# ASVspoof2019_LA_asv_scores
# ASVspoof2019_LA_cm_protocols
# ASVspoof2019_LA_dev
# ASVspoof2019_LA_eval
# ASVspoof2019_LA_train
# README.LA.txt

# %%
import torch

if torch.cuda.is_available():
    print("✅ GPU Connected!")
    print(f"GPU Name: {torch.cuda.get_device_name(0)}")
    print(f"Total Memory: {torch.cuda.get_device_properties(0).total_memory / 1e9:.2f} GB")
else:
    print("❌ No GPU — Running on CPU only")
# Out:
# ✅ GPU Connected!
# GPU Name: NVIDIA A100-SXM4-40GB
# Total Memory: 42.41 GB

# %%
# !nvidia-smi
# Out:
# Thu May  7 12:54:14 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 570.86.15              Driver Version: 570.86.15      CUDA Version: 12.8     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA A100-SXM4-40GB          On  |   00000000:01:00.0 Off |                    0 |
# | N/A   66C    P0            278W /  275W |   16352MiB /  40960MiB |    100%      Default |
# |                                         |                        |             Disabled |
# ...
